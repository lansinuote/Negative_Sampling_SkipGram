# %%
from nltk.corpus import wordnet


def load_node():
    #全体词表,取出主词
    node = list({i.name().split('.')[0] for i in wordnet.all_synsets()})

    #全体可能的同义词
    #all_lemma_names是无重复的
    lemma = list(wordnet.all_lemma_names())

    #合并node和lemma,其实node基本上是lemma的子集,只多了4个词
    node = list(set(node + lemma))

    #编码
    node = {name: i for i, name in enumerate(node)}

    return node


node = load_node()

len(node), node['girl']
# Out:
# (147311, 73123)

# %%
def load_edge():
    #所有的关系
    edge_fs = [
        'synsets', 'hypernyms', 'hyponyms', 'instance_hyponyms',
        'member_meronyms', 'part_meronyms', 'topic_domains', 'usage_domains',
        'region_domains', 'attributes', 'entailments', 'causes', 'also_sees',
        'verb_groups', 'similar_tos', 'lemma_names'
    ]

    edge = []

    #全体词表
    for n1 in node.keys():

        #遍历同义词
        for synset in wordnet.synsets(n1):
            n2 = synset.name().split('.')[0]

            #添加同义词关系
            edge.append((n1, n2))

            #遍历所有可能的关系
            for f in edge_fs:
                #同义词刚刚已经处理过了,这里不再重复
                if f == 'synsets':
                    continue

                #调用同义词上的edge函数
                for n2 in getattr(synset, f)():
                    if f == 'lemma_names':
                        n2 = n2.lower()
                    else:
                        n2 = n2.name().split('.')[0]
                    edge.append((n1, n2))

    #删除所有自己到自己的关联
    #编码
    edge = [(node[i[0]], node[i[1]]) for i in edge if i[0] != i[1]]

    return edge


edge = load_edge()

len(edge), edge[:15]
# Out:
# (1022595,
#  [(2, 117854),
#   (2, 121790),
#   (2, 8137),
#   (2, 54195),
#   (3, 98401),
#   (3, 4697),
#   (3, 98401),
#   (3, 4697),
#   (4, 15540),
#   (4, 115369),
#   (5, 121100),
#   (6, 140980),
#   (6, 63977),
#   (6, 36451),
#   (6, 123276)])

# %%
import torch
import random

edge_set = set(edge)


def get_batch():
    sample = random.sample(edge, 128)

    pos = []
    neg = []
    for i in sample:
        n1, n2 = i
        while (n1, n2) in edge_set:
            n1 = random.randint(0, len(node) - 1)
        neg.append((n1, n2))

        n1, n2 = i
        while (n1, n2) in edge_set:
            n2 = random.randint(0, len(node) - 1)
        neg.append((n1, n2))

        pos.append(i)
        pos.append(i)

    pos = torch.LongTensor(pos)
    neg = torch.LongTensor(neg)

    return pos, neg


get_batch()
# Out:
# (tensor([[ 25540,  28902],
#          [ 25540,  28902],
#          [116118,  25345],
#          [116118,  25345],
#          [ 81782,  49763],
#          [ 81782,  49763],
#          [ 78927,  61715],
#          [ 78927,  61715],
#          [ 95352,  95272],
#          [ 95352,  95272],
#          [ 29257,  63276],
#          [ 29257,  63276],
#          [ 91624, 146374],
#          [ 91624, 146374],
#          [146374,  77592],
#          [146374,  77592],
#          [ 79753,  80034],
#          [ 79753,  80034],
#          [120815,  59600],
#          [120815,  59600],
#          [126600,  34256],
#          [126600,  34256],
#          [  4613,  28360],
#          [  4613,  28360],
#          [ 40318,   8057],
#          [ 40318,   8057],
#          [ 34769, 131205],
#          [ 34769, 131205],
#          [ 66247,  85162],
#          [ 66247,  85162],
#          [ 41153,  57616],
#          [ 41153,  57616],
#          [137484,  73803],
#          [137484,  73803],
#          [144460,  43499],
#          [144460,  43499],
#          [ 12201, 105067],
#          [ 12201, 105067],
#          [104716,  49964],
#          [104716,  49964],
#          [125499,  66806],
#          [125499,  66806],
#          [ 68904, 104696],
#          [ 68904, 104696],
#          [115921, 141433],
#          [115921, 141433],
#          [133880,  96822],
#          [133880,  96822],
#          [ 22162,  97718],
#          [ 22162,  97718],
#          [ 23578, 128211],
#          [ 23578, 128211],
#          [146090,  21479],
#          [146090,  21479],
#          [ 81956,  95600],
#          [ 81956,  95600],
#          [ 18422, 140311],
#          [ 18422, 140311],
#          [ 14001, 129834],
#          [ 14001, 129834],
#          [  4652,  72906],
#          [  4652,  72906],
#          [ 64211, 118030],
#          [ 64211, 118030],
#          [ 15121, 111377],
#          [ 15121, 111377],
#          [ 27280, 104863],
#          [ 27280, 104863],
#          [113262, 133440],
#          [113262, 133440],
#          [100494,  61691],
#          [100494,  61691],
#          [127458,  57824],
#          [127458,  57824],
#          [  6583,  12346],
#          [  6583,  12346],
#          [110575,  37774],
#          [110575,  37774],
#          [ 88886,  16497],
#          [ 88886,  16497],
#          [ 22744,  68356],
#          [ 22744,  68356],
#          [ 44332,  83115],
#          [ 44332,  83115],
#          [ 18952, 128230],
#          [ 18952, 128230],
#          [128321,  19384],
#          [128321,  19384],
#          [ 12360,  28493],
#          [ 12360,  28493],
#          [128608,   5138],
#          [128608,   5138],
#          [ 74369, 142577],
#          [ 74369, 142577],
#          [ 82300, 107319],
#          [ 82300, 107319],
#          [ 42288,  72704],
#          [ 42288,  72704],
#          [ 62225,  76479],
#          [ 62225,  76479],
#          [116521,  61878],
#          [116521,  61878],
#          [101224, 134376],
#          [101224, 134376],
#          [ 66307,  63392],
#          [ 66307,  63392],
#          [116682,  42671],
#          [116682,  42671],
#          [102733,  14001],
#          [102733,  14001],
#          [ 36627, 125662],
#          [ 36627, 125662],
#          [ 17750,  50613],
#          [ 17750,  50613],
#          [134607, 125259],
#          [134607, 125259],
#          [ 99027,  32070],
#          [ 99027,  32070],
#          [ 63883,  77472],
#          [ 63883,  77472],
#          [ 93087, 118749],
#          [ 93087, 118749],
#          [ 30051,  19402],
#          [ 30051,  19402],
#          [ 77681,  60446],
#          [ 77681,  60446],
#          [115789, 115698],
#          [115789, 115698],
#          [ 57857,   3394],
#          [ 57857,   3394],
#          [118291,  61434],
#          [118291,  61434],
#          [ 51286,  83078],
#          [ 51286,  83078],
#          [ 93515, 127905],
#          [ 93515, 127905],
#          [ 22377,  75700],
#          [ 22377,  75700],
#          [136375,  85916],
#          [136375,  85916],
#          [ 47611,  59108],
#          [ 47611,  59108],
#          [ 23624,  38790],
#          [ 23624,  38790],
#          [ 67481,  49018],
#          [ 67481,  49018],
#          [ 35170,  27924],
#          [ 35170,  27924],
#          [138152, 125950],
#          [138152, 125950],
#          [109538,   8526],
#          [109538,   8526],
#          [134416, 129214],
#          [134416, 129214],
#          [ 71167, 120923],
#          [ 71167, 120923],
#          [112687,  54961],
#          [112687,  54961],
#          [ 26249,  20901],
#          [ 26249,  20901],
#          [  4184, 102282],
#          [  4184, 102282],
#          [ 48172, 132393],
#          [ 48172, 132393],
#          [115986,  39405],
#          [115986,  39405],
#          [139892, 131244],
#          [139892, 131244],
#          [ 44553, 106181],
#          [ 44553, 106181],
#          [ 97140,  29486],
#          [ 97140,  29486],
#          [ 29095,  75800],
#          [ 29095,  75800],
#          [ 53889,   4853],
#          [ 53889,   4853],
#          [ 95326,  96013],
#          [ 95326,  96013],
#          [ 82941,  72105],
#          [ 82941,  72105],
#          [124690,  32220],
#          [124690,  32220],
#          [ 56821, 113717],
#          [ 56821, 113717],
#          [106430,  41882],
#          [106430,  41882],
#          [ 85397, 130833],
#          [ 85397, 130833],
#          [ 30063, 118177],
#          [ 30063, 118177],
#          [   254, 102221],
#          [   254, 102221],
#          [ 21393, 125102],
#          [ 21393, 125102],
#          [141341,  71371],
#          [141341,  71371],
#          [ 39003,  35908],
#          [ 39003,  35908],
#          [ 82398,  87702],
#          [ 82398,  87702],
#          [ 76788,  90238],
#          [ 76788,  90238],
#          [ 45445, 130997],
#          [ 45445, 130997],
#          [114568,  93541],
#          [114568,  93541],
#          [ 26566,  16170],
#          [ 26566,  16170],
#          [ 76560,  32883],
#          [ 76560,  32883],
#          [ 24615,  98238],
#          [ 24615,  98238],
#          [ 43425,    753],
#          [ 43425,    753],
#          [ 71307,  80085],
#          [ 71307,  80085],
#          [102110,  19570],
#          [102110,  19570],
#          [107698,  58151],
#          [107698,  58151],
#          [ 17760,  89207],
#          [ 17760,  89207],
#          [ 77700,  22596],
#          [ 77700,  22596],
#          [101698,  84892],
#          [101698,  84892],
#          [145971,  52429],
#          [145971,  52429],
#          [ 14335, 122855],
#          [ 14335, 122855],
#          [ 72227,  39650],
#          [ 72227,  39650],
#          [ 95395, 139696],
#          [ 95395, 139696],
#          [145136, 141110],
#          [145136, 141110],
#          [  5838,  79358],
#          [  5838,  79358],
#          [ 96351,   8496],
#          [ 96351,   8496],
#          [ 61434, 120923],
#          [ 61434, 120923],
#          [ 43604, 146717],
#          [ 43604, 146717],
#          [ 13282,  29077],
#          [ 13282,  29077],
#          [ 74756,  26392],
#          [ 74756,  26392],
#          [117511,  11037],
#          [117511,  11037],
#          [116529, 129155],
#          [116529, 129155],
#          [ 13685, 118221],
#          [ 13685, 118221],
#          [ 22877,  53547],
#          [ 22877,  53547]]),
#  tensor([[113605,  28902],
#          [ 25540,   4688],
#          [ 79802,  25345],
#          [116118,   4280],
#          [117413,  49763],
#          [ 81782, 126770],
#          [142545,  61715],
#          [ 78927,  62022],
#          [ 35112,  95272],
#          [ 95352,  79939],
#          [ 62181,  63276],
#          [ 29257,  34046],
#          [ 93940, 146374],
#          [ 91624, 122880],
#          [ 93332,  77592],
#          [146374, 110834],
#          [ 97121,  80034],
#          [ 79753,  72648],
#          [122763,  59600],
#          [120815,  62573],
#          [ 66510,  34256],
#          [126600,  79036],
#          [ 68656,  28360],
#          [  4613,  54086],
#          [130008,   8057],
#          [ 40318,  76799],
#          [ 74313, 131205],
#          [ 34769, 108386],
#          [ 35524,  85162],
#          [ 66247,  89761],
#          [ 98096,  57616],
#          [ 41153,  55163],
#          [106727,  73803],
#          [137484,  25643],
#          [134907,  43499],
#          [144460,  67177],
#          [ 41129, 105067],
#          [ 12201, 107897],
#          [ 37999,  49964],
#          [104716,  38896],
#          [ 51140,  66806],
#          [125499,  54482],
#          [ 34823, 104696],
#          [ 68904,  69420],
#          [ 62092, 141433],
#          [115921,  84697],
#          [122987,  96822],
#          [133880,  29937],
#          [ 88370,  97718],
#          [ 22162, 118405],
#          [139883, 128211],
#          [ 23578, 105771],
#          [141271,  21479],
#          [146090,  10226],
#          [ 57796,  95600],
#          [ 81956,  84245],
#          [135699, 140311],
#          [ 18422,  17745],
#          [ 29732, 129834],
#          [ 14001,  78621],
#          [142256,  72906],
#          [  4652, 143754],
#          [ 66611, 118030],
#          [ 64211,  69141],
#          [116635, 111377],
#          [ 15121, 139012],
#          [141207, 104863],
#          [ 27280,  94943],
#          [ 79919, 133440],
#          [113262,  20310],
#          [  5118,  61691],
#          [100494, 100902],
#          [103550,  57824],
#          [127458,  52238],
#          [115343,  12346],
#          [  6583,  86390],
#          [ 17688,  37774],
#          [110575, 110770],
#          [138532,  16497],
#          [ 88886, 112467],
#          [ 26038,  68356],
#          [ 22744,   8950],
#          [ 70679,  83115],
#          [ 44332, 126652],
#          [ 21665, 128230],
#          [ 18952, 118541],
#          [ 83761,  19384],
#          [128321,  81845],
#          [ 36488,  28493],
#          [ 12360, 146707],
#          [ 88652,   5138],
#          [128608,  19343],
#          [ 81116, 142577],
#          [ 74369,  40462],
#          [ 65267, 107319],
#          [ 82300,  11799],
#          [ 63274,  72704],
#          [ 42288,  37682],
#          [ 97188,  76479],
#          [ 62225, 135752],
#          [ 42960,  61878],
#          [116521,  67029],
#          [130187, 134376],
#          [101224,  65959],
#          [ 53752,  63392],
#          [ 66307,  44434],
#          [ 98105,  42671],
#          [116682, 100147],
#          [ 74399,  14001],
#          [102733, 139176],
#          [ 51552, 125662],
#          [ 36627,  28625],
#          [123795,  50613],
#          [ 17750,  90376],
#          [ 52280, 125259],
#          [134607,  98354],
#          [103343,  32070],
#          [ 99027, 117438],
#          [ 80425,  77472],
#          [ 63883,  54813],
#          [ 85722, 118749],
#          [ 93087,  88620],
#          [ 45613,  19402],
#          [ 30051,  93917],
#          [ 17823,  60446],
#          [ 77681, 130766],
#          [ 12541, 115698],
#          [115789, 124458],
#          [  6066,   3394],
#          [ 57857,  66701],
#          [ 25760,  61434],
#          [118291, 111924],
#          [ 24148,  83078],
#          [ 51286,  89329],
#          [ 37182, 127905],
#          [ 93515,  55717],
#          [  1665,  75700],
#          [ 22377,  53988],
#          [  9001,  85916],
#          [136375, 127536],
#          [ 24828,  59108],
#          [ 47611,  49589],
#          [ 39903,  38790],
#          [ 23624,  35011],
#          [ 67863,  49018],
#          [ 67481,  42285],
#          [117399,  27924],
#          [ 35170, 103425],
#          [ 96110, 125950],
#          [138152,  85193],
#          [ 98146,   8526],
#          [109538,   6737],
#          [127851, 129214],
#          [134416, 122538],
#          [ 39980, 120923],
#          [ 71167,  15274],
#          [109016,  54961],
#          [112687,  68382],
#          [ 91448,  20901],
#          [ 26249,  96560],
#          [ 46695, 102282],
#          [  4184,  68423],
#          [ 25540, 132393],
#          [ 48172,  98905],
#          [ 89484,  39405],
#          [115986, 124514],
#          [  1334, 131244],
#          [139892,  32443],
#          [ 66063, 106181],
#          [ 44553,  11844],
#          [ 14999,  29486],
#          [ 97140,  32312],
#          [144516,  75800],
#          [ 29095,  67895],
#          [ 63472,   4853],
#          [ 53889, 132181],
#          [ 71228,  96013],
#          [ 95326,  13109],
#          [ 94567,  72105],
#          [ 82941, 115445],
#          [ 74040,  32220],
#          [124690, 123562],
#          [115851, 113717],
#          [ 56821,  34262],
#          [128683,  41882],
#          [106430,  84425],
#          [108174, 130833],
#          [ 85397, 139115],
#          [ 46733, 118177],
#          [ 30063,  76974],
#          [ 54616, 102221],
#          [   254,   1989],
#          [131706, 125102],
#          [ 21393, 120007],
#          [ 98713,  71371],
#          [141341, 119655],
#          [119613,  35908],
#          [ 39003,  54760],
#          [  1114,  87702],
#          [ 82398, 145720],
#          [ 50316,  90238],
#          [ 76788, 134653],
#          [ 10571, 130997],
#          [ 45445,  38790],
#          [ 53986,  93541],
#          [114568,  81509],
#          [ 27968,  16170],
#          [ 26566,  45569],
#          [116670,  32883],
#          [ 76560,   8837],
#          [ 76321,  98238],
#          [ 24615,  76177],
#          [ 43900,    753],
#          [ 43425,  92591],
#          [133549,  80085],
#          [ 71307, 134327],
#          [126779,  19570],
#          [102110, 107043],
#          [ 73839,  58151],
#          [107698,  65301],
#          [122455,  89207],
#          [ 17760, 113506],
#          [119917,  22596],
#          [ 77700,  45874],
#          [ 39563,  84892],
#          [101698,  39551],
#          [ 74666,  52429],
#          [145971,  91719],
#          [ 53404, 122855],
#          [ 14335,  85738],
#          [ 29732,  39650],
#          [ 72227,  17890],
#          [ 33218, 139696],
#          [ 95395,  10641],
#          [128672, 141110],
#          [145136,  24691],
#          [123142,  79358],
#          [  5838, 138775],
#          [ 25545,   8496],
#          [ 96351,  76076],
#          [120944, 120923],
#          [ 61434,  67959],
#          [107818, 146717],
#          [ 43604,  93844],
#          [ 81829,  29077],
#          [ 13282,  38846],
#          [ 59383,  26392],
#          [ 74756, 109058],
#          [ 97787,  11037],
#          [117511,  57737],
#          [109588, 129155],
#          [116529,  69628],
#          [143238, 118221],
#          [ 13685, 111872],
#          [131606,  53547],
#          [ 22877,   2511]]))

# %%
def get_cos_loss(pos, neg):
    #pos -> [8, 2, 2]
    #neg -> [8, 2, 2]

    #[8, 1, 2]
    pos_n1 = pos[:, 0].unsqueeze(dim=1)
    #[8, 2, 1]
    pos_n2 = pos[:, 1].unsqueeze(dim=2)

    #[8, 1, 2],[8, 2, 1] -> [8]
    loss_pos = torch.bmm(pos_n1, pos_n2).squeeze()

    #[8, 1, 2]
    neg_n1 = neg[:, 0].unsqueeze(dim=1)
    #[8, 2, 1]
    neg_n2 = neg[:, 1].unsqueeze(dim=2)

    #[8, 1, 2],[8, 2, 1] -> [8]
    loss_neg = torch.bmm(neg_n1, -neg_n2).squeeze()

    #[8, 2] -> [8]
    loss_pos = loss_pos.sigmoid().clip(min=1e-8).log()

    #[8, 2] -> [8]
    loss_neg = loss_neg.sigmoid().clip(min=1e-8).log()

    return -(loss_pos + loss_neg).mean()


a, b = torch.randn(8, 2, 2), torch.randn(8, 2, 2)
get_cos_loss(a, b)
# Out:
# tensor(2.3421)

# %%
class Model(torch.nn.Module):

    def __init__(self):
        super().__init__()

        #V是词汇量
        self.embed = torch.nn.Embedding(num_embeddings=len(node),
                                        embedding_dim=150)

        #初始化参数
        self.embed.weight.data.uniform_(-0.01, 0.01)

    def forward(self, pos, neg):
        #编码
        #[8, 6] -> [8, 6, 2]
        pos = self.embed(pos)

        #[8, 12] -> [8, 12, 2]
        neg = self.embed(neg)

        return get_cos_loss(pos, neg)


model = Model()

model(*get_batch())
# Out:
# tensor(1.3863, grad_fn=<NegBackward0>)

# %%
def test(test_words):
    embed = model.embed.weight.data.clone()
    node_keys = list(node.keys())

    for word in test_words:
        x = embed[node[word]]
        score = torch.nn.functional.cosine_similarity(x, embed)
        topk = score.topk(k=5).indices
        topk = [node_keys[k] for k in topk]
        print(word, topk)


test(['girl', 'bus', 'green', 'doctor', 'dog', 'queen', 'italy'])
# Out:
# girl ['girl', 'aleksandr_nikolayevich_scriabin', 'gobiesox_strumosus', 'diltiazem', 'patriotic']
# bus ['bus', 'ineluctable', 'begum', 'lilac-blue', 'quick_time']
# green ['green', 'golden_fern', 'keep_to_oneself', 'exterminable', 'movie']
# doctor ['doctor', 'nonpasserine', 'redstart', 'uncombined', 'announce']
# dog ['dog', 'virtuous', 'rock_sandwort', 'cattle', 'bestialise']
# queen ['queen', 'crossbench', 'dhal', 'hydrologist', 'wild_sarsaparilla']
# italy ['italy', 'rear_admiral', 'hokan', 'shipmate', 'family_tupaiidae']

# %%
def train():
    global model
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = model.to(device)

    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    loss_sum = 0
    for epoch in range(2000001):
        batch = get_batch()
        batch = [i.to(device) for i in batch]

        loss = model(*batch)
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        loss_sum += loss.item()

        if epoch % 10000 == 0:
            print(epoch, loss_sum)
            test(['girl', 'bus', 'green', 'doctor', 'dog', 'queen', 'italy'])
            loss_sum = 0

        if epoch % 100000 == 0:
            torch.save(model.cpu(), 'models/wordnet_%d.model' % epoch)
            model = model.to(device)

    model = model.cpu()


train()
# Out:
# 0 1.3862968683242798
# girl ['girl', 'aleksandr_nikolayevich_scriabin', 'gobiesox_strumosus', 'diltiazem', 'patriotic']
# bus ['bus', 'ineluctable', 'begum', 'lilac-blue', 'quick_time']
# green ['green', 'golden_fern', 'keep_to_oneself', 'exterminable', 'movie']
# doctor ['doctor', 'nonpasserine', 'redstart', 'uncombined', 'announce']
# dog ['dog', 'virtuous', 'rock_sandwort', 'cattle', 'bestialise']
# queen ['queen', 'crossbench', 'dhal', 'hydrologist', 'wild_sarsaparilla']
# italy ['italy', 'rear_admiral', 'hokan', 'shipmate', 'family_tupaiidae']
# 10000 10527.33760380745
# girl ['girl', 'missy', 'fille', 'young_lady', 'sweater_girl']
# bus ['bus', 'jitney', 'buss', 'motorbus', 'charabanc']
# green ['green', 'greens', 'viridity', 'light-green', 'greenishness']
# doctor ['doctor', 'physician', 'doc', 'extern', 'dr.']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'leonberg', 'perisher']
# queen ['queen', 'queens', 'female_monarch', 'mary_queen_of_scots', 'queen_regnant']
# italy ['italy', 'italian_republic', 'italia', 'liguria', 'brescia']
# 20000 7835.991330623627
# girl ['girl', 'young_woman', 'fille', 'missy', 'young_lady']
# bus ['bus', 'jitney', 'motorbus', 'buss', 'charabanc']
# green ['green', 'greens', 'village_green', 'viridity', 'leafy_vegetable']
# doctor ['doctor', 'doc', 'dr.', 'physician', 'medico']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'chase_after', 'chased']
# queen ['queen', 'queens', 'female_monarch', 'mary_queen_of_scots', 'fagot']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'liguria']
# 30000 7502.4985229969025
# girl ['girl', 'young_woman', 'fille', 'young_lady', 'missy']
# bus ['bus', 'buss', 'motorbus', 'jitney', 'passenger_vehicle']
# green ['green', 'greens', 'viridity', 'village_green', 'greenness']
# doctor ['doctor', 'doc', 'dr.', 'physician', 'medico']
# dog ['dog', 'canis_familiaris', 'domestic_dog', 'chased', 'tailed']
# queen ['queen', 'queens', 'female_monarch', 'queen_regnant', 'face_card']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'liguria']
# 40000 7465.384823977947
# girl ['girl', 'young_woman', 'fille', 'missy', 'young_lady']
# bus ['bus', 'buss', 'autobus', 'jitney', 'omnibus']
# green ['green', 'greens', 'viridity', 'village_green', 'olive_green']
# doctor ['doctor', 'dr.', 'physician', 'doc', 'medico']
# dog ['dog', 'canis_familiaris', 'domestic_dog', 'chased', 'go_after']
# queen ['queen', 'queens', 'face_card', 'chessman', 'queen_regnant']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'trentino-alto_adige']
# 50000 7499.209786653519
# girl ['girl', 'young_woman', 'young_lady', 'sweater_girl', 'missy']
# bus ['bus', 'buss', 'jitney', 'autobus', 'minibus']
# green ['green', 'greens', 'viridity', 'leafy_vegetable', 'greenness']
# doctor ['doctor', 'physician', 'doc', 'dr.', 'md']
# dog ['dog', 'canis_familiaris', 'domestic_dog', 'tailed', 'chased']
# queen ['queen', 'queens', 'queen_regnant', 'queen_of_england', 'poove']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'alps']
# 60000 7545.954997301102
# girl ['girl', 'young_woman', 'missy', 'fille', 'sweater_girl']
# bus ['bus', 'autobus', 'buss', 'jitney', 'motorbus']
# green ['green', 'greens', 'viridity', 'leafy_vegetable', 'greenness']
# doctor ['doctor', 'physician', 'doc', 'dr.', 'medico']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'cad', 'tracking']
# queen ['queen', 'queens', 'queen_regnant', 'isabella', 'royal_line']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'alps']
# 70000 7609.773991882801
# girl ['girl', 'young_woman', 'young_lady', 'missy', 'fille']
# bus ['bus', 'jitney', 'autobus', 'charabanc', 'buss']
# green ['green', 'greens', 'viridity', 'greenness', 'leafy_vegetable']
# doctor ['doctor', 'physician', 'dr.', 'doc', 'md']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'cad', 'tailed']
# queen ['queen', 'queens', 'queen_regnant', 'female_monarch', 'isabella']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'austria']
# 80000 7675.773131966591
# girl ['girl', 'young_woman', 'missy', 'young_lady', 'fille']
# bus ['bus', 'jitney', 'buss', 'autobus', 'charabanc']
# green ['green', 'greens', 'viridity', 'greenness', 'chromatic_color']
# doctor ['doctor', 'doc', 'physician', 'dr.', 'medico']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'tailed', 'cad']
# queen ['queen', 'queens', 'queen_regnant', 'fagot', 'king']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'alps']
# 90000 7733.014671981335
# girl ['girl', 'young_woman', 'young_lady', 'fille', 'missy']
# bus ['bus', 'buss', 'jitney', 'charabanc', 'motorbus']
# green ['green', 'greens', 'greenness', 'viridity', 'yellow_green']
# doctor ['doctor', 'dr.', 'physician', 'doc', 'md']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'tailed', 'hound']
# queen ['queen', 'queens', 'fagot', 'female_monarch', 'queen_regnant']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'alps']
# 100000 7799.04526168108
# girl ['girl', 'young_lady', 'young_woman', 'fille', 'sweater_girl']
# bus ['bus', 'buss', 'charabanc', 'autobus', 'jitney']
# green ['green', 'greens', 'greenness', 'chromatic_color', 'leafy_vegetable']
# doctor ['doctor', 'physician', 'dr.', 'doc', 'medico']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'trailing', 'track']
# queen ['queen', 'queens', 'fagot', 'picture_card', 'queen_regnant']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'alps']
# 110000 7853.95482814312
# girl ['girl', 'young_lady', 'fille', 'young_woman', 'missy']
# bus ['bus', 'buss', 'jitney', 'omnibus', 'autobus']
# green ['green', 'greens', 'chromatic_color', 'greenness', 'leafy_vegetable']
# doctor ['doctor', 'physician', 'medico', 'dr.', 'doc']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'dogged', 'track']
# queen ['queen', 'queens', 'fagot', 'female_monarch', 'picture_card']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'basilicata']
# 120000 7907.907329797745
# girl ['girl', 'young_lady', 'fille', 'young_woman', 'missy']
# bus ['bus', 'buss', 'omnibus', 'passenger_vehicle', 'motorcoach']
# green ['green', 'greens', 'greenness', 'park', 'chromatic_color']
# doctor ['doctor', 'medico', 'physician', 'dr.', 'doc']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'track', 'dogged']
# queen ['queen', 'queens', 'tabby', 'picture_card', 'personification']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'basilicata']
# 130000 7956.0360051989555
# girl ['girl', 'young_lady', 'young_woman', 'miss', 'missy']
# bus ['bus', 'buss', 'autobus', 'omnibus', 'trolleybus']
# green ['green', 'greens', 'leafy_vegetable', 'park', 'viridity']
# doctor ['doctor', 'medico', 'physician', 'dr.', 'doc']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'heel', 'track']
# queen ['queen', 'queens', 'fagot', 'king', 'tabby']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'basilicata']
# 140000 7996.014741182327
# girl ['girl', 'young_woman', 'young_lady', 'missy', 'miss']
# bus ['bus', 'buss', 'trolleybus', 'omnibus', 'motorcoach']
# green ['green', 'greens', 'leafy_vegetable', 'colours', 'chromatic_color']
# doctor ['doctor', 'medico', 'physician', 'doc', 'dr.']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'tracking', 'track']
# queen ['queen', 'queens', 'picture_card', 'female_monarch', 'queen_regnant']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'basilicata']
# 150000 8040.832614541054
# girl ['girl', 'young_woman', 'young_lady', 'miss', 'female_child']
# bus ['bus', 'buss', 'trolleybus', 'car', 'coach']
# green ['green', 'greens', 'greenness', 'chromatic', 'park']
# doctor ['doctor', 'medico', 'doc', 'physician', 'repair']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'tracking', 'track']
# queen ['queen', 'queens', 'picture_card', 'poove', 'female_monarch']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'basilicata']
# 160000 8076.61440551281
# girl ['girl', 'young_woman', 'young_lady', 'woman', 'miss']
# bus ['bus', 'double-decker', 'motorbus', 'charabanc', 'car']
# green ['green', 'greens', 'chromatic', 'park', 'greenness']
# doctor ['doctor', 'medico', 'doc', 'physician', 'dr.']
# dog ['dog', 'domestic_dog', 'canis_familiaris', 'track', 'trailing']
# queen ['queen', 'queens', 'female_monarch', 'poove', 'king']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'basilicata']
# 170000 8123.10838162899
# girl ['girl', 'young_woman', 'young_lady', 'woman', 'miss']
# bus ['bus', 'charabanc', 'buss', 'double-decker', 'motorbus']
# green ['green', 'greens', 'chromatic', 'park', 'greenness']
# doctor ['doctor', 'medico', 'md', 'doc', 'fix']
# dog ['dog', 'domestic_dog', 'track', 'hound', 'chase']
# queen ['queen', 'queens', 'female_monarch', 'drift', 'king']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'piedmont']
# 180000 8155.00337523222
# girl ['girl', 'young_woman', 'young_lady', 'miss', 'woman']
# bus ['bus', 'buss', 'car', 'double-decker', 'charabanc']
# green ['green', 'greens', 'chromatic', 'park', 'greenness']
# doctor ['doctor', 'doc', 'md', 'medico', 'repair']
# dog ['dog', 'domestic_dog', 'chase', 'track', 'canis_familiaris']
# queen ['queen', 'queens', 'picture_card', 'female_monarch', 'female_aristocrat']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'italian']
# 190000 8187.046461999416
# girl ['girl', 'young_woman', 'miss', 'young_lady', 'woman']
# bus ['bus', 'buss', 'car', 'coach', 'motorbus']
# green ['green', 'greens', 'chromatic', 'park', 'greenness']
# doctor ['doctor', 'medico', 'repair', 'md', 'physician']
# dog ['dog', 'chase', 'domestic_dog', 'tracking', 'track']
# queen ['queen', 'queens', 'picture_card', 'nance', 'tabby']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'italian']
# 200000 8211.073756694794
# girl ['girl', 'young_woman', 'young_lady', 'miss', 'missy']
# bus ['bus', 'buss', 'car', 'coach', 'motorbus']
# green ['green', 'greens', 'park', 'greenness', 'chromatic']
# doctor ['doctor', 'medico', 'physician', 'doc', 'md']
# dog ['dog', 'chase', 'wiener', 'poll', 'run_down']
# queen ['queen', 'queens', 'nance', 'tabby', 'female_monarch']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'italian']
# 210000 8242.459014892578
# girl ['girl', 'young_woman', 'miss', 'young_lady', 'missy']
# bus ['bus', 'buss', 'coach', 'car', 'heaps']
# green ['green', 'greens', 'greenness', 'leafy_vegetable', 'park']
# doctor ['doctor', 'medico', 'physician', 'repair', 'induce']
# dog ['dog', 'chase', 'track', 'trailing', 'run_down']
# queen ['queen', 'queens', 'king', 'man', 'men']
# italy ['italy', 'italia', 'italian_republic', 'italian', 'italian_region']
# 220000 8263.572462379932
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'missy']
# bus ['bus', 'buss', 'coach', 'motorbus', 'heaps']
# green ['green', 'greens', 'colours', 'chromatic', 'greenness']
# doctor ['doctor', 'medico', 'md', 'dr.', 'physician']
# dog ['dog', 'chase', 'track', 'trailing', 'run_down']
# queen ['queen', 'queens', 'king', 'drift', 'faggot']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'italian']
# 230000 8296.834795713425
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'missy']
# bus ['bus', 'buss', 'drive', 'coach', 'car']
# green ['green', 'greens', 'purple', 'colours', 'greenness']
# doctor ['doctor', 'md', 'medico', 'physician', 'dr.']
# dog ['dog', 'track', 'check', 'run_down', 'tracking']
# queen ['queen', 'queens', 'king', 'faggot', 'female_monarch']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'italian']
# 240000 8322.108519673347
# girl ['girl', 'young_woman', 'young_lady', 'miss', 'missy']
# bus ['bus', 'buss', 'coach', 'heaps', 'car']
# green ['green', 'greens', 'purple', 'colours', 'greenness']
# doctor ['doctor', 'physician', 'md', 'medico', 'doc']
# dog ['dog', 'poodle', 'blackguard', 'sounding', 'domestic_dog']
# queen ['queen', 'queens', 'king', 'faggot', 'pouf']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'spain']
# 250000 8342.466886520386
# girl ['girl', 'young_woman', 'fille', 'miss', 'young_lady']
# bus ['bus', 'buss', 'heap', 'have', 'coach']
# green ['green', 'greens', 'purple', 'greenness', 'colouring']
# doctor ['doctor', 'md', 'physician', 'medico', 'doc']
# dog ['dog', 'chase', 'sounding', 'check', 'track']
# queen ['queen', 'queens', 'king', 'faggot', 'man']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'italian']
# 260000 8379.55279636383
# girl ['girl', 'young_woman', 'miss', 'fille', 'young_lady']
# bus ['bus', 'buss', 'taking', 'come', 'car']
# green ['green', 'greens', 'park', 'colouring', 'greenness']
# doctor ['doctor', 'physician', 'md', 'medico', 'fix']
# dog ['dog', 'check', 'chase', 'pursue', 'stretch']
# queen ['queen', 'queens', 'faggot', 'female_monarch', 'fagot']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'italian']
# 270000 8386.564198374748
# girl ['girl', 'young_woman', 'miss', 'missy', 'fille']
# bus ['bus', 'buss', 'car', 'heap', 'drive']
# green ['green', 'greens', 'purple', 'park', 'colouring']
# doctor ['doctor', 'md', 'medico', 'physician', 'change_state']
# dog ['dog', 'chase', 'take', 'dally', 'exhausted']
# queen ['queen', 'queens', 'faggot', 'female_monarch', 'fagot']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'alps']
# 280000 8417.359292984009
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'fille']
# bus ['bus', 'buss', 'car', 'coach', 'heap']
# green ['green', 'greens', 'colouring', 'park', 'purple']
# doctor ['doctor', 'md', 'medico', 'physician', 'working']
# dog ['dog', 'chase', 'accommodate', 'heel', 'move']
# queen ['queen', 'queens', 'king', 'faggot', 'female_monarch']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'sabine']
# 290000 8442.070454657078
# girl ['girl', 'miss', 'young_lady', 'young_woman', 'fille']
# bus ['bus', 'car', 'buss', 'level', 'public_transport']
# green ['green', 'greens', 'park', 'colors', 'purple']
# doctor ['doctor', 'md', 'medico', 'physician', 'repair']
# dog ['dog', 'heel', 'chase', 'issue', 'tail']
# queen ['queen', 'queens', 'fagot', 'faggot', 'verify']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'sabine']
# 300000 8461.957721352577
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'lose']
# bus ['bus', 'car', 'buss', 'automobile', 'machine']
# green ['green', 'greens', 'park', 'chromatic', 'colors']
# doctor ['doctor', 'md', 'medico', 'dr.', 'physician']
# dog ['dog', 'trap', 'domestic_dog', 'chase', 'kept']
# queen ['queen', 'queens', 'queer', 'fag', 'effects']
# italy ['italy', 'italian_republic', 'italia', 'city', 'port']
# 310000 8470.717396259308
# girl ['girl', 'young_lady', 'miss', 'young_woman', 'fille']
# bus ['bus', 'car', 'buss', 'auto', 'trolleybus']
# green ['green', 'greens', 'colors', 'park', 'purple']
# doctor ['doctor', 'md', 'physician', 'doc', 'medico']
# dog ['dog', 'pierce', 'chase', 'bring', 'bang']
# queen ['queen', 'queens', 'fagot', 'female_monarch', 'king']
# italy ['italy', 'italia', 'italian_republic', 'city', 'italian_region']
# 320000 8489.451952457428
# girl ['girl', 'miss', 'young_lady', 'young_woman', 'lose']
# bus ['bus', 'car', 'buss', 'trolleybus', 'double-decker']
# green ['green', 'greens', 'park', 'chromatic', 'purple']
# doctor ['doctor', 'medico', 'md', 'given', 'physician']
# dog ['dog', 'chase', 'bang', 'breaking', 'accommodate']
# queen ['queen', 'queens', 'fagot', 'king', 'nance']
# italy ['italy', 'italia', 'italian_republic', 'city', 'italian_region']
# 330000 8494.843615949154
# girl ['girl', 'young_lady', 'miss', 'young_woman', 'fille']
# bus ['bus', 'car', 'buss', 'automobile', 'double-decker']
# green ['green', 'greens', 'discolor', 'digs', 'chromatic']
# doctor ['doctor', 'medico', 'md', 'physician', 'mend']
# dog ['dog', 'chase', 'issue', 'seat', 'bang']
# queen ['queen', 'queens', 'king', 'royal_line', 'fagot']
# italy ['italy', 'italia', 'italian_republic', 'italian', 'city']
# 340000 8517.835182487965
# girl ['girl', 'miss', 'young_lady', 'young_woman', 'fille']
# bus ['bus', 'car', 'trolleybus', 'motorbus', 'double-decker']
# green ['green', 'greens', 'chromatic', 'orange', 'park']
# doctor ['doctor', 'medico', 'physician', 'md', 'mend']
# dog ['dog', 'chase', 'bang', 'tails', 'quest']
# queen ['queen', 'queens', 'king', 'nance', 'run']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'italian']
# 350000 8539.5100299716
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'fille']
# bus ['bus', 'car', 'coach', 'heap', 'buss']
# green ['green', 'greens', 'k', 'orange', 'site']
# doctor ['doctor', 'medico', 'physician', 'dr.', 'md']
# dog ['dog', 'chase', 'run_down', 'tracked', 'search']
# queen ['queen', 'queens', 'driven', 'individual', 'device']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'germany']
# 360000 8558.566155672073
# girl ['girl', 'miss', 'young_lady', 'fille', 'young_woman']
# bus ['bus', 'car', 'automobile', 'coach', 'buss']
# green ['green', 'greens', 'k', 'site', 'greenness']
# doctor ['doctor', 'medico', 'dr.', 'physician', 'doc']
# dog ['dog', 'run_down', 'quest', 'bang', 'tracked']
# queen ['queen', 'queens', 'device', 'grounds', 'driven']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'metropolis']
# 370000 8564.151451826096
# girl ['girl', 'miss', 'young_lady', 'woman', 'fille']
# bus ['bus', 'car', 'buss', 'coach', 'auto']
# green ['green', 'greens', 'k', 'site', 'dig']
# doctor ['doctor', 'medico', 'physician', 'dr.', 'doc']
# dog ['dog', 'tracked', 'run_down', 'search', 'tail']
# queen ['queen', 'queens', 'driven', 'soul', 'grounds']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'germany']
# 380000 8581.40454441309
# girl ['girl', 'miss', 'young_lady', 'fille', 'woman']
# bus ['bus', 'car', 'drive', 'coach', 'smack']
# green ['green', 'greens', 'k', 'chromatic', 'park']
# doctor ['doctor', 'medico', 'dr.', 'physician', 'doc']
# dog ['dog', 'tail', 'stimulate', 'carry', 'chase']
# queen ['queen', 'queens', 'effect', 'result', 'driven']
# italy ['italy', 'italia', 'italian_republic', 'germany', 'italian_region']
# 390000 8591.343240916729
# girl ['girl', 'miss', 'fille', 'young_lady', 'young_woman']
# bus ['bus', 'car', 'distribute', 'found', 'heap']
# green ['green', 'greens', 'k', 'chromatic', 'understand']
# doctor ['doctor', 'medico', 'dr.', 'physician', 'doc']
# dog ['dog', 'run_down', 'tail', 'fundament', 'chase']
# queen ['queen', 'queens', 'result', 'rise', 'effect']
# italy ['italy', 'italia', 'italian_republic', 'germany', 'italian_region']
# 400000 8598.825862526894
# girl ['girl', 'miss', 'fille', 'young_lady', 'missy']
# bus ['bus', 'draw', 'car', 'distribute', 'drive']
# green ['green', 'greens', 'k', 'hit', 'greenness']
# doctor ['doctor', 'dr.', 'md', 'medico', 'doc']
# dog ['dog', 'tail', 'run_down', 'chase', 'hound']
# queen ['queen', 'queens', 'rise', 'elapse', 'grade']
# italy ['italy', 'italia', 'italian_republic', 'germany', 'terrorism']
# 410000 8607.979586184025
# girl ['girl', 'miss', 'young_lady', 'fille', 'young_woman']
# bus ['bus', 'going', 'drive', 'draw', 'train']
# green ['green', 'greens', 'color', 'k', 'colors']
# doctor ['doctor', 'md', 'medico', 'dr.', 'doc']
# dog ['dog', 'canis_familiaris', 'run_down', 'tail', 'takings']
# queen ['queen', 'queens', 'rise', 'driven', 'meeting']
# italy ['italy', 'italia', 'italian_republic', 'terrorism', 'germany']
# 420000 8632.385136246681
# girl ['girl', 'miss', 'young_lady', 'young_woman', 'fille']
# bus ['bus', 'thrust', 'drive', 'acts', 'going']
# green ['green', 'greens', 'feel', 'color', 'drawn']
# doctor ['doctor', 'dr.', 'doc', 'medico', 'md']
# dog ['dog', 'canis_familiaris', 'run_down', 'track', 'chase']
# queen ['queen', 'queens', 'rise', 'style', 'promote']
# italy ['italy', 'italia', 'italian_republic', 'alps', 'terrorism']
# 430000 8644.33892583847
# girl ['girl', 'miss', 'young_lady', 'young_woman', 'female_child']
# bus ['bus', 'acts', 'car', 'coach', 'buss']
# green ['green', 'greens', 'feel', 'colour', 'chromatic']
# doctor ['doctor', 'doc', 'dr.', 'rush', 'repair']
# dog ['dog', 'canis_familiaris', 'run_down', 'check', 'get_laid']
# queen ['queen', 'queens', 'promote', 'fagot', 'control']
# italy ['italy', 'italia', 'italian_republic', 'alps', 'terrorism']
# 440000 8655.729979813099
# girl ['girl', 'miss', 'young_lady', 'female_child', 'young_woman']
# bus ['bus', 'coach', 'buss', 'acts', 'blowing']
# green ['green', 'greens', 'drawn', 'feel', 'colour']
# doctor ['doctor', 'doc', 'medico', 'dr.', 'repair']
# dog ['dog', 'run_down', 'withdraw', 'suffer', 'push']
# queen ['queen', 'queens', 'fagot', 'sort', 'promote']
# italy ['italy', 'italia', 'italian_republic', 'terrorism', 'spain']
# 450000 8654.18356949091
# girl ['girl', 'miss', 'young_lady', 'young_woman', 'missy']
# bus ['bus', 'automobile', 'coach', 'buss', 'receive']
# green ['green', 'greens', 'interpret', 'k', 'chromatic']
# doctor ['doctor', 'dr.', 'medico', 'physician', 'learn']
# dog ['dog', 'run_down', 'suffer', 'moved', 'played']
# queen ['queen', 'queens', 'faggot', 'fagot', 'sort']
# italy ['italy', 'italia', 'italian_republic', 'terrorism', 'spain']
# 460000 8662.590096592903
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'dame']
# bus ['bus', 'continue', 'findings', 'driving', 'drawing']
# green ['green', 'greens', 'k', 'interpret', 'blowing']
# doctor ['doctor', 'physician', 'dr.', 'doc', 'medico']
# dog ['dog', 'run_down', 'stimulate', 'take', 'quest']
# queen ['queen', 'queens', 'fagot', 'promote', 'occur']
# italy ['italy', 'italia', 'italian_republic', 'alps', 'evoke']
# 470000 8683.967113435268
# girl ['girl', 'miss', 'young_woman', 'woman', 'fille']
# bus ['bus', 'findings', 'acts', 'coach', 'drawing']
# green ['green', 'greens', 'k', 'blowing', 'interpret']
# doctor ['doctor', 'physician', 'doc', 'dr.', 'medico']
# dog ['dog', 'pursue', 'tail', 'quest', 'domestic_dog']
# queen ['queen', 'queens', 'fagot', 'promote', 'trouncing']
# italy ['italy', 'italia', 'italian_republic', 'alps', 'italian_region']
# 480000 8678.361794054508
# girl ['girl', 'miss', 'young_woman', 'dame', 'fille']
# bus ['bus', 'driving', 'drive', 'buss', 'drawing']
# green ['green', 'greens', 'k', 'colors', 'interpret']
# doctor ['doctor', 'physician', 'dr.', 'medico', 'doc']
# dog ['dog', 'run_down', 'take', 'jazz', 'seat']
# queen ['queen', 'queens', 'involuntary', 'fagot', 'fag']
# italy ['italy', 'italia', 'italian_republic', 'alps', 'italian']
# 490000 8689.811968564987
# girl ['girl', 'miss', 'young_woman', 'dame', 'fille']
# bus ['bus', 'coach', 'buss', 'roof', 'public_transport']
# green ['green', 'greens', 'interpret', 'park', 'flip']
# doctor ['doctor', 'physician', 'doc', 'md', 'dr.']
# dog ['dog', 'takings', 'take', 'jazz', 'chase']
# queen ['queen', 'queens', 'fag', 'fly', 'king']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'italian']
# 500000 8712.868220090866
# girl ['girl', 'miss', 'young_woman', 'fille', 'dame']
# bus ['bus', 'roof', 'drive', 'acting', 'coach']
# green ['green', 'greens', 'colour', 'colors', 'color']
# doctor ['doctor', 'doc', 'dr.', 'physician', 'medico']
# dog ['dog', 'run_down', 'takings', 'take', 'pursue']
# queen ['queen', 'queens', 'king', 'fly', 'flies']
# italy ['italy', 'italia', 'italian_republic', 'italian', 'italian_region']
# 510000 8696.614781677723
# girl ['girl', 'miss', 'young_woman', 'fille', 'dame']
# bus ['bus', 'roof', 'double-decker', 'coach', 'be']
# green ['green', 'greens', 'color', 'toss', 'picking']
# doctor ['doctor', 'doc', 'physician', 'dr.', 'md']
# dog ['dog', 'pursue', 'admit', 'run_down', 'get_laid']
# queen ['queen', 'queens', 'king', 'creature', 'queer']
# italy ['italy', 'italia', 'italian_republic', 'alps', 'ireland']
# 520000 8710.860908210278
# girl ['girl', 'miss', 'young_woman', 'dame', 'fille']
# bus ['bus', 'roof', 'motorcoach', 'push', 'buss']
# green ['green', 'greens', 'toss', 'colour', 'colors']
# doctor ['doctor', 'physician', 'md', 'medico', 'dr.']
# dog ['dog', 'admit', 'moved', 'tail', 'run_down']
# queen ['queen', 'queens', 'king', 'chess', 'queer']
# italy ['italy', 'italia', 'italian_republic', 'alps', 'germany']
# 530000 8722.175256431103
# girl ['girl', 'miss', 'young_woman', 'missed', 'missy']
# bus ['bus', 'be', 'push', 'put_up', 'roof']
# green ['green', 'greens', 'chromatic_color', 'toss', 'colors']
# doctor ['doctor', 'medico', 'physician', 'md', 'dr.']
# dog ['dog', 'admit', 'clog', 'make_out', 'claim']
# queen ['queen', 'queens', 'king', 'queer', 'royalty']
# italy ['italy', 'italia', 'italian_republic', 'germany', 'spain']
# 540000 8739.037509262562
# girl ['girl', 'miss', 'missy', 'fille', 'woman']
# bus ['bus', 'push', 'drive', 'charabanc', 'reckon']
# green ['green', 'greens', 'toss', 'colour', 'color']
# doctor ['doctor', 'physician', 'doc', 'medico', 'dr.']
# dog ['dog', 'frank', 'make_out', 'admit', 'quest']
# queen ['queen', 'queens', 'royalty', 'chess', 'king']
# italy ['italy', 'italia', 'italian_republic', 'spain', 'european_nation']
# 550000 8731.256290912628
# girl ['girl', 'miss', 'woman', 'missy', 'young_woman']
# bus ['bus', 'coach', 'buss', 'double-decker', 'exist']
# green ['green', 'greens', 'colour', 'colors', 'park']
# doctor ['doctor', 'dr.', 'physician', 'doc', 'medico']
# dog ['dog', 'frank', 'tug', 'run_down', 'chase']
# queen ['queen', 'queens', 'find', 'queer', 'flies']
# italy ['italy', 'italia', 'italian_republic', 'spain', 'austria']
# 560000 8747.873451769352
# girl ['girl', 'miss', 'young_woman', 'fille', 'woman']
# bus ['bus', 'coach', 'heaps', 'buss', 'auto']
# green ['green', 'greens', 'colour', 'chromatic_color', 'colors']
# doctor ['doctor', 'dr.', 'doc', 'medico', 'physician']
# dog ['dog', 'tug', 'make_out', 'admit', 'use']
# queen ['queen', 'queens', 'promote', 'fagot', 'find']
# italy ['italy', 'italia', 'italian_republic', 'metropolis', 'urban_center']
# 570000 8742.292772591114
# girl ['girl', 'fille', 'miss', 'missy', 'young_woman']
# bus ['bus', 'buss', 'auto', 'coach', 'blue']
# green ['green', 'greens', 'colour', 'colors', 'color']
# doctor ['doctor', 'dr.', 'physician', 'doc', 'medico']
# dog ['dog', 'make_out', 'pursue', 'tug', 'admit']
# queen ['queen', 'queens', 'promote', 'fagot', 'frustrate']
# italy ['italy', 'italia', 'italian_republic', 'city', 'russian_federation']
# 580000 8758.05969953537
# girl ['girl', 'fille', 'miss', 'young_woman', 'missy']
# bus ['bus', 'articulate', 'heaps', 'buss', 'coach']
# green ['green', 'greens', 'colour', 'tract', 'colours']
# doctor ['doctor', 'dr.', 'doc', 'medico', 'physician']
# dog ['dog', 'hound', 'chase', 'attempt', 'moved']
# queen ['queen', 'queens', 'nance', 'fagot', 'queer']
# italy ['italy', 'italian_republic', 'italia', 'russian_federation', 'city']
# 590000 8762.10306495428
# girl ['girl', 'miss', 'fille', 'young_woman', 'missy']
# bus ['bus', 'coach', 'buss', 'heaps', 'faggot']
# green ['green', 'greens', 'colour', 'colours', 'lot']
# doctor ['doctor', 'dr.', 'doc', 'physician', 'medico']
# dog ['dog', 'chase', 'hound', 'travel', 'tag']
# queen ['queen', 'queens', 'royalty', 'fagot', 'queer']
# italy ['italy', 'italian_republic', 'italia', 'germany', 'russian_federation']
# 600000 8770.848267257214
# girl ['girl', 'miss', 'fille', 'young_woman', 'woman']
# bus ['bus', 'coach', 'bring', 'car', 'buss']
# green ['green', 'greens', 'colors', 'colours', 'colour']
# doctor ['doctor', 'dr.', 'doc', 'physician', 'medico']
# dog ['dog', 'chase', 'canis_familiaris', 'tag', 'domestic_dog']
# queen ['queen', 'queens', 'royalty', 'female_aristocrat', 'ram']
# italy ['italy', 'italian_republic', 'italia', 'germany', 'port']
# 610000 8768.496117830276
# girl ['girl', 'miss', 'fille', 'woman', 'dame']
# bus ['bus', 'coach', 'buss', 'school', 'motorcoach']
# green ['green', 'greens', 'colors', 'bring', 'chromatic']
# doctor ['doctor', 'dr.', 'doc', 'medico', 'physician']
# dog ['dog', 'chase', 'issue', 'travel', 'gone']
# queen ['queen', 'queens', 'royalty', 'effects', 'flying']
# italy ['italy', 'italian_republic', 'italia', 'germany', 'italian_region']
# 620000 8768.065190374851
# girl ['girl', 'miss', 'woman', 'fille', 'adult_female']
# bus ['bus', 'coach', 'buss', 'school', 'car']
# green ['green', 'greens', 'colors', 'bring', 'impression']
# doctor ['doctor', 'doc', 'dr.', 'fix', 'physician']
# dog ['dog', 'chase', 'canis_familiaris', 'gone', 'choke']
# queen ['queen', 'queens', 'royalty', 'range', 'precipitate']
# italy ['italy', 'italian_republic', 'italia', 'pitched_battle', 'port']
# 630000 8770.79966366291
# girl ['girl', 'miss', 'woman', 'fille', 'young_lady']
# bus ['bus', 'coach', 'buss', 'car', 'motorcoach']
# green ['green', 'greens', 'colors', 'knock', 'string']
# doctor ['doctor', 'doc', 'dr.', 'physician', 'repair']
# dog ['dog', 'crash', 'hound', 'tag', 'chase']
# queen ['queen', 'queens', 'royalty', 'fagot', 'variety']
# italy ['italy', 'italia', 'italian_republic', 'germany', 'pitched_battle']
# 640000 8774.801901519299
# girl ['girl', 'miss', 'fille', 'young_lady', 'woman']
# bus ['bus', 'coach', 'car', 'buss', 'motorbus']
# green ['green', 'greens', 'impression', 'colors', 'parks']
# doctor ['doctor', 'physician', 'doc', 'dr.', 'medico']
# dog ['dog', 'chase', 'hound', 'crash', 'tag']
# queen ['queen', 'queens', 'effects', 'blow', 'struck']
# italy ['italy', 'italia', 'italian_republic', 'eec', 'france']
# 650000 8773.22433668375
# girl ['girl', 'miss', 'woman', 'fille', 'young_lady']
# bus ['bus', 'car', 'buss', 'coach', 'motorbus']
# green ['green', 'greens', 'colours', 'flood', 'lot']
# doctor ['doctor', 'dr.', 'physician', 'doc', 'medico']
# dog ['dog', 'tag', 'steal', 'chase', 'chase_after']
# queen ['queen', 'queens', 'blow', 'travel', 'struck']
# italy ['italy', 'italia', 'italian_republic', 'eec', 'alps']
# 660000 8789.90636253357
# girl ['girl', 'woman', 'miss', 'fille', 'young_woman']
# bus ['bus', 'car', 'buss', 'machine', 'public_transport']
# green ['green', 'greens', 'colours', 'flood', 'chromatic_color']
# doctor ['doctor', 'doc', 'dr.', 'physician', 'medico']
# dog ['dog', 'apply', 'pursue', 'tail', 'tag']
# queen ['queen', 'queens', 'travel', 'arise', 'meeting']
# italy ['italy', 'italian_republic', 'italia', 'eec', 'germany']
# 670000 8798.55210006237
# girl ['girl', 'miss', 'woman', 'fille', 'young_woman']
# bus ['bus', 'buss', 'public_transport', 'car', 'motorbus']
# green ['green', 'greens', 'colours', 'chromatic', 'left']
# doctor ['doctor', 'dr.', 'doc', 'physician', 'md']
# dog ['dog', 'pursue', 'tag', 'apply', 'tail']
# queen ['queen', 'queens', 'happen', 'harmonize', 'arise']
# italy ['italy', 'italian_republic', 'italia', 'germany', 'pitched_battle']
# 680000 8792.06751191616
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'fille']
# bus ['bus', 'buss', 'car', 'public_transport', 'automobile']
# green ['green', 'greens', 'colours', 'breaking', 'locate']
# doctor ['doctor', 'physician', 'dr.', 'doc', 'md']
# dog ['dog', 'pursue', 'tag', 'flag', 'giving']
# queen ['queen', 'queens', 'faggot', 'promote', 'drive']
# italy ['italy', 'italian_republic', 'italia', 'germany', 'urban_center']
# 690000 8794.119726777077
# girl ['girl', 'miss', 'fille', 'young_lady', 'young_woman']
# bus ['bus', 'public_transport', 'buss', 'car', 'automobile']
# green ['green', 'greens', 'colours', 'breaking', 'cutting']
# doctor ['doctor', 'dr.', 'physician', 'doc', 'md']
# dog ['dog', 'tag', 'pursue', 'taken', 'run_down']
# queen ['queen', 'queens', 'blow', 'drive', 'approach']
# italy ['italy', 'italian_republic', 'italia', 'urban_center', 'germany']
# 700000 8794.290655553341
# girl ['girl', 'miss', 'young_lady', 'fille', 'demand']
# bus ['bus', 'buss', 'public_transport', 'coach', 'car']
# green ['green', 'greens', 'colours', 'colour', 'coloring']
# doctor ['doctor', 'dr.', 'physician', 'doc', 'md']
# dog ['dog', 'run_down', 'tag', 'pursue', 'flag']
# queen ['queen', 'queens', 'blow', 'flying', 'approach']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'pitched_battle']
# 710000 8814.251872599125
# girl ['girl', 'miss', 'young_lady', 'demand', 'fille']
# bus ['bus', 'public_transport', 'buss', 'coach', 'car']
# green ['green', 'greens', 'coloring', 'k', 'chromatic']
# doctor ['doctor', 'dr.', 'physician', 'doc', 'medico']
# dog ['dog', 'run_down', 'chase_after', 'pursue', 'transport']
# queen ['queen', 'queens', 'cat', 'blow', 'happen']
# italy ['italy', 'italia', 'italian_republic', 'ireland', 'metropolis']
# 720000 8798.85555279255
# girl ['girl', 'miss', 'fille', 'young_lady', 'young_woman']
# bus ['bus', 'buss', 'public_transport', 'coach', 'car']
# green ['green', 'greens', 'colours', 'colour', 'park']
# doctor ['doctor', 'dr.', 'physician', 'medico', 'doc']
# dog ['dog', 'pursue', 'follow', 'transport', 'run_down']
# queen ['queen', 'queens', 'happen', 'bind', 'see']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'germany']
# 730000 8806.67072314024
# girl ['girl', 'miss', 'blow', 'young_woman', 'young_lady']
# bus ['bus', 'buss', 'public_transport', 'coach', 'double-decker']
# green ['green', 'greens', 'k', 'park', 'chromatic_color']
# doctor ['doctor', 'dr.', 'physician', 'medico', 'md']
# dog ['dog', 'follow', 'driven', 'proceeds', 'pursue']
# queen ['queen', 'queens', 'happen', 'check', 'cat']
# italy ['italy', 'italia', 'italian_region', 'italian_republic', 'ireland']
# 740000 8810.450908601284
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'checked']
# bus ['bus', 'buss', 'coach', 'public_transport', 'declare']
# green ['green', 'greens', 'k', 'color', 'chromatic_color']
# doctor ['doctor', 'physician', 'dr.', 'medico', 'md']
# dog ['dog', 'pursue', 'hound', 'treat', 'chase_after']
# queen ['queen', 'queens', 'happen', 'moderate', 'cat']
# italy ['italy', 'italian_republic', 'italian_region', 'italia', 'ireland']
# 750000 8818.113170027733
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'dame']
# bus ['bus', 'buss', 'public_transport', 'coach', 'car']
# green ['green', 'greens', 'color', 'k', 'colour']
# doctor ['doctor', 'physician', 'medico', 'dr.', 'md']
# dog ['dog', 'pursue', 'hound', 'level', 'control']
# queen ['queen', 'queens', 'fag', 'happen', 'cat']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'basilicata']
# 760000 8816.75190281868
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'missy']
# bus ['bus', 'buss', 'slew', 'spatter', 'babble']
# green ['green', 'greens', 'k', 'color', 'colour']
# doctor ['doctor', 'physician', 'dr.', 'medico', 'md']
# dog ['dog', 'run_down', 'domestic_dog', 'search', 'chase']
# queen ['queen', 'queens', 'fag', 'connected', 'binding']
# italy ['italy', 'italian_region', 'italian_republic', 'italia', 'mexico']
# 770000 8807.41715836525
# girl ['girl', 'miss', 'young_woman', 'missy', 'young_lady']
# bus ['bus', 'buss', 'coach', 'posed', 'draw']
# green ['green', 'greens', 'k', 'colors', 'color']
# doctor ['doctor', 'physician', 'medico', 'dr.', 'md']
# dog ['dog', 'run_down', 'domestic_dog', 'search', 'chase']
# queen ['queen', 'queens', 'fag', 'raise', 'queer']
# italy ['italy', 'italian_republic', 'italian_region', 'italia', 'portugal']
# 780000 8835.600167930126
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'missy']
# bus ['bus', 'buss', 'posed', 'draw', 'taken']
# green ['green', 'greens', 'k', 'tract', 'chromatic']
# doctor ['doctor', 'physician', 'dr.', 'medico', 'md']
# dog ['dog', 'search', 'track', 'hound', 'run_down']
# queen ['queen', 'queens', 'queer', 'fag', 'king']
# italy ['italy', 'italian_republic', 'italian_region', 'italia', 'fto']
# 790000 8825.874175310135
# girl ['girl', 'miss', 'young_woman', 'missy', 'young_lady']
# bus ['bus', 'buss', 'slump', 'putting', 'taken']
# green ['green', 'greens', 'color', 'colored', 'k']
# doctor ['doctor', 'dr.', 'physician', 'medico', 'md']
# dog ['dog', 'chase', 'engage', 'search', 'tell']
# queen ['queen', 'queens', 'queer', 'king', 'come_up']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'urban_center']
# 800000 8828.131215333939
# girl ['girl', 'miss', 'young_woman', 'missy', 'dame']
# bus ['bus', 'buss', 'stoop', 'car', 'coach']
# green ['green', 'greens', 'k', 'bends', 'chromatic']
# doctor ['doctor', 'physician', 'dr.', 'md', 'doc']
# dog ['dog', 'chase', 'search', 'sign', 'hound']
# queen ['queen', 'queens', 'king', 'rex', 'playing_card']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'pitched_battle']
# 810000 8826.844942510128
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'dame']
# bus ['bus', 'buss', 'put', 'drive', 'coach']
# green ['green', 'greens', 'park', 'decorate', 'colors']
# doctor ['doctor', 'dr.', 'physician', 'medico', 'md']
# dog ['dog', 'chase', 'search', 'hound', 'sign']
# queen ['queen', 'queens', 'king', 'playing_card', 'rex']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'urban_center']
# 820000 8831.99753421545
# girl ['girl', 'miss', 'young_woman', 'dame', 'missy']
# bus ['bus', 'buss', 'put', 'coach', 'car']
# green ['green', 'greens', 'park', 'colors', 'parcel']
# doctor ['doctor', 'dr.', 'physician', 'medico', 'doc']
# dog ['dog', 'search', 'chase', 'hound', 'hunt']
# queen ['queen', 'queens', 'playing_card', 'king', 'male_monarch']
# italy ['italy', 'italian_republic', 'italian_region', 'italia', 'urban_center']
# 830000 8832.052170693874
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'missy']
# bus ['bus', 'buss', 'coach', 'put', 'car']
# green ['green', 'greens', 'park', 'color', 'colored']
# doctor ['doctor', 'physician', 'dr.', 'medico', 'doc']
# dog ['dog', 'search', 'hunt', 'chase', 'hound']
# queen ['queen', 'queens', 'male_monarch', 'king', 'playing_card']
# italy ['italy', 'italian_region', 'italian_republic', 'italia', 'germany']
# 840000 8828.584123969078
# girl ['girl', 'miss', 'young_lady', 'missy', 'young_woman']
# bus ['bus', 'buss', 'stack', 'coach', 'descend']
# green ['green', 'greens', 'colored', 'chromatic', 'park']
# doctor ['doctor', 'physician', 'doc', 'medico', 'md']
# dog ['dog', 'search', 'chase', 'hound', 'do_it']
# queen ['queen', 'queens', 'king', 'queer', 'male_monarch']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'germany']
# 850000 8845.075452923775
# girl ['girl', 'young_lady', 'miss', 'young_woman', 'missy']
# bus ['bus', 'buss', 'coach', 'double-decker', 'car']
# green ['green', 'greens', 'chromatic', 'colours', 'color']
# doctor ['doctor', 'physician', 'medico', 'doc', 'dr.']
# dog ['dog', 'chase', 'search', 'hound', 'domestic_dog']
# queen ['queen', 'queens', 'king', 'male_monarch', 'harbor']
# italy ['italy', 'italian_republic', 'italian_region', 'italia', 'urban_center']
# 860000 8836.660992860794
# girl ['girl', 'miss', 'young_lady', 'young_woman', 'fille']
# bus ['bus', 'buss', 'car', 'coach', 'double-decker']
# green ['green', 'greens', 'chromatic', 'butt', 'draw']
# doctor ['doctor', 'medico', 'dr.', 'repair', 'physician']
# dog ['dog', 'hound', 'pursue', 'domestic_dog', 'search']
# queen ['queen', 'queens', 'male_monarch', 'playing_card', 'king']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'colombia']
# 870000 8841.358240485191
# girl ['girl', 'miss', 'young_lady', 'young_woman', 'missy']
# bus ['bus', 'buss', 'coach', 'car', 'public_transport']
# green ['green', 'greens', 'butt', 'settle', 'toss']
# doctor ['doctor', 'dr.', 'medico', 'physician', 'doc']
# dog ['dog', 'pursue', 'domestic_dog', 'chase', 'hound']
# queen ['queen', 'queens', 'male_monarch', 'playing_card', 'area']
# italy ['italy', 'italian_republic', 'italian_region', 'italia', 'sicily']
# 880000 8849.707821071148
# girl ['girl', 'young_woman', 'miss', 'young_lady', 'fille']
# bus ['bus', 'car', 'buss', 'coach', 'riding']
# green ['green', 'greens', 'butt', 'colour', 'colouring']
# doctor ['doctor', 'dr.', 'medico', 'physician', 'doc']
# dog ['dog', 'chase', 'pursue', 'domestic_dog', 'trail']
# queen ['queen', 'queens', 'house', 'king', 'chess']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'urban_center']
# 890000 8848.215521991253
# girl ['girl', 'young_woman', 'young_lady', 'miss', 'fille']
# bus ['bus', 'buss', 'coach', 'car', 'riding']
# green ['green', 'greens', 'butt', 'colour', 'determine']
# doctor ['doctor', 'medico', 'dr.', 'repair', 'md']
# dog ['dog', 'chase', 'pursue', 'domestic_dog', 'quest']
# queen ['queen', 'queens', 'playing_card', 'drift', 'rise']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'denmark']
# 900000 8846.22534930706
# girl ['girl', 'young_woman', 'young_lady', 'miss', 'missy']
# bus ['bus', 'coach', 'buss', 'car', 'riding']
# green ['green', 'greens', 'colouring', 'colour', 'chromatic']
# doctor ['doctor', 'medico', 'dr.', 'doc', 'physician']
# dog ['dog', 'search', 'make_out', 'pursue', 'affect']
# queen ['queen', 'queens', 'playing_card', 'drift', 'pouf']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'sicily']
# 910000 8849.041643381119
# girl ['girl', 'young_woman', 'young_lady', 'miss', 'fille']
# bus ['bus', 'buss', 'car', 'coach', 'riding']
# green ['green', 'greens', 'k', 'can', 'colouring']
# doctor ['doctor', 'medico', 'repair', 'dr.', 'md']
# dog ['dog', 'affect', 'touch', 'pursue', 'confirm']
# queen ['queen', 'queens', 'drawing', 'drawn', 'drift']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'denmark']
# 920000 8845.746627748013
# girl ['girl', 'young_woman', 'miss', 'young_lady', 'missy']
# bus ['bus', 'buss', 'coach', 'car', 'heaps']
# green ['green', 'greens', 'colouring', 'chromatic', 'k']
# doctor ['doctor', 'medico', 'physician', 'repair', 'dr.']
# dog ['dog', 'frank', 'chase', 'shine', 'touch']
# queen ['queen', 'queens', 'drift', 'drawing', 'playing_card']
# italy ['italy', 'italia', 'italian_region', 'italian_republic', 'urban_center']
# 930000 8864.004580378532
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'fille']
# bus ['bus', 'coach', 'buss', 'car', 'passenger_vehicle']
# green ['green', 'greens', 'forbid', 'colouring', 'k']
# doctor ['doctor', 'medico', 'physician', 'dr.', 'md']
# dog ['dog', 'frank', 'chase', 'domestic_dog', 'tag']
# queen ['queen', 'queens', 'playing_card', 'drawing', 'bind']
# italy ['italy', 'italia', 'italian_region', 'italian_republic', 'commercial_enterprise']
# 940000 8852.69848626852
# girl ['girl', 'miss', 'young_lady', 'missy', 'young_woman']
# bus ['bus', 'coach', 'buss', 'drive', 'car']
# green ['green', 'greens', 'k', 'belt', 'bends']
# doctor ['doctor', 'medico', 'physician', 'dr.', 'repair']
# dog ['dog', 'domestic_dog', 'frank', 'seek', 'canis_familiaris']
# queen ['queen', 'queens', 'playing_card', 'drawing', 'section']
# italy ['italy', 'italian_republic', 'italia', 'italian_region', 'urban_center']
# 950000 8856.720691978931
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'fille']
# bus ['bus', 'coach', 'car', 'motorcoach', 'buss']
# green ['green', 'greens', 'harmonize', 'chromatic', 'bends']
# doctor ['doctor', 'dr.', 'medico', 'physician', 'repair']
# dog ['dog', 'domestic_dog', 'frank', 'trailing', 'cuss']
# queen ['queen', 'queens', 'faggot', 'checked', 'king']
# italy ['italy', 'italian_republic', 'italia', 'pitched_battle', 'germany']
# 960000 8856.743384599686
# girl ['girl', 'young_lady', 'miss', 'young_woman', 'missy']
# bus ['bus', 'coach', 'car', 'passenger_vehicle', 'motorcoach']
# green ['green', 'greens', 'color', 'chromatic', 'harmonize']
# doctor ['doctor', 'dr.', 'medico', 'physician', 'repair']
# dog ['dog', 'domestic_dog', 'pursue', 'tagged', 'chase']
# queen ['queen', 'queens', 'drawing', 'playing_card', 'faggot']
# italy ['italy', 'italia', 'italian_republic', 'spain', 'pitched_battle']
# 970000 8857.102682292461
# girl ['girl', 'young_woman', 'young_lady', 'miss', 'missy']
# bus ['bus', 'coach', 'ride', 'car', 'removed']
# green ['green', 'greens', 'chromatic', 'greenness', 'raise']
# doctor ['doctor', 'dr.', 'medico', 'physician', 'repair']
# dog ['dog', 'domestic_dog', 'tag', 'tagged', 'chase_after']
# queen ['queen', 'queens', 'playing_card', 'drawing', 'faggot']
# italy ['italy', 'italia', 'italian_republic', 'pitched_battle', 'germany']
# 980000 8852.512466013432
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'fille']
# bus ['bus', 'buss', 'coach', 'car', 'level']
# green ['green', 'greens', 'chromatic', 'make', 'color']
# doctor ['doctor', 'medico', 'repair', 'bring', 'dr.']
# dog ['dog', 'hound', 'chase', 'tails', 'tail']
# queen ['queen', 'queens', 'playing_card', 'pansy', 'departed']
# italy ['italy', 'italia', 'italian_republic', 'germany', 'italian_region']
# 990000 8851.652941167355
# girl ['girl', 'miss', 'missy', 'young_woman', 'young_lady']
# bus ['bus', 'buss', 'omnibus', 'passenger_vehicle', 'coach']
# green ['green', 'greens', 'chromatic', 'park', 'colors']
# doctor ['doctor', 'medico', 'physician', 'dr.', 'bring']
# dog ['dog', 'hound', 'tails', 'tail', 'chase']
# queen ['queen', 'queens', 'playing_card', 'seat', 'king']
# italy ['italy', 'italia', 'italian_republic', 'land', 'ireland']
# 1000000 8852.857169866562
# girl ['girl', 'miss', 'young_lady', 'missy', 'young_woman']
# bus ['bus', 'car', 'buss', 'omnibus', 'motorcoach']
# green ['green', 'greens', 'greenness', 'chromatic', 'common']
# doctor ['doctor', 'physician', 'dr.', 'medico', 'set_up']
# dog ['dog', 'chase', 'stops', 'tails', 'tail']
# queen ['queen', 'queens', 'seat', 'faggot', 'variety']
# italy ['italy', 'italia', 'italian_republic', 'ireland', 'spain']
# 1010000 8870.543743491173
# girl ['girl', 'miss', 'young_lady', 'fille', 'demand']
# bus ['bus', 'buss', 'double-decker', 'conductor', 'omnibus']
# green ['green', 'greens', 'chromatic', 'color', 'burn']
# doctor ['doctor', 'physician', 'dr.', 'medico', 'doc']
# dog ['dog', 'run_down', 'quest', 'hound', 'domestic_dog']
# queen ['queen', 'queens', 'king', 'faggot', 'seat']
# italy ['italy', 'italia', 'italian_republic', 'ireland', 'eu']
# 1020000 8853.951002836227
# girl ['girl', 'miss', 'young_lady', 'woman', 'fille']
# bus ['bus', 'buss', 'coach', 'double-decker', 'passenger_vehicle']
# green ['green', 'greens', 'make', 'back', 'turn']
# doctor ['doctor', 'provide', 'signalize', 'doc', 'physician']
# dog ['dog', 'hound', 'domestic_dog', 'flag', 'pursue']
# queen ['queen', 'queens', 'king', 'faggot', 'tie']
# italy ['italy', 'italia', 'italian_republic', 'metropolis', 'urban_center']
# 1030000 8867.288074433804
# girl ['girl', 'miss', 'woman', 'young_lady', 'young_woman']
# bus ['bus', 'buss', 'car', 'coach', 'passenger_vehicle']
# green ['green', 'greens', 'chromatic', 'colors', 'color']
# doctor ['doctor', 'physician', 'doc', 'md', 'dr.']
# dog ['dog', 'domestic_dog', 'swear', 'hunted', 'canis_familiaris']
# queen ['queen', 'queens', 'marks', 'faggot', 'king']
# italy ['italy', 'italia', 'italian_republic', 'urban_center', 'metropolis']
# 1040000 8853.075695991516
# girl ['girl', 'miss', 'woman', 'young_lady', 'young_woman']
# bus ['bus', 'coach', 'buss', 'car', 'passenger_vehicle']
# green ['green', 'greens', 'colors', 'chromatic', 'park']
# doctor ['doctor', 'physician', 'dr.', 'doc', 'md']
# dog ['dog', 'span', 'swear', 'domestic_dog', 'andiron']
# queen ['queen', 'queens', 'faggot', 'marks', 'tie']
# italy ['italy', 'italia', 'italian_republic', 'urban_center', 'city']
# 1050000 8865.103113353252
# girl ['girl', 'miss', 'young_lady', 'woman', 'demand']
# bus ['bus', 'buss', 'car', 'coach', 'roof']
# green ['green', 'greens', 'park', 'colors', 'chromatic']
# doctor ['doctor', 'dr.', 'md', 'physician', 'doc']
# dog ['dog', 'span', 'quest', 'run_down', 'hound']
# queen ['queen', 'queens', 'queer', 'fly', 'king']
# italy ['italy', 'italia', 'italian_republic', 'terrorist_group', 'italian_region']
# 1060000 8863.404060840607
# girl ['girl', 'miss', 'young_lady', 'young_woman', 'woman']
# bus ['bus', 'buss', 'coach', 'car', 'machine']
# green ['green', 'greens', 'colors', 'park', 'suffer']
# doctor ['doctor', 'physician', 'dr.', 'md', 'medico']
# dog ['dog', 'run_down', 'trying', 'give_chase', 'heel']
# queen ['queen', 'queens', 'queer', 'fly', 'king']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'urban_center']
# 1070000 8860.267274916172
# girl ['girl', 'miss', 'young_lady', 'fille', 'young_woman']
# bus ['bus', 'buss', 'heaps', 'wad', 'coach']
# green ['green', 'greens', 'parcel', 'colors', 'serve']
# doctor ['doctor', 'dr.', 'physician', 'doc', 'md']
# dog ['dog', 'trying', 'quest', 'run_down', 'click']
# queen ['queen', 'queens', 'queer', 'travelled', 'approach']
# italy ['italy', 'italia', 'italian_republic', 'urban_center', 'italian_region']
# 1080000 8865.965131223202
# girl ['girl', 'miss', 'young_lady', 'young_woman', 'fille']
# bus ['bus', 'buss', 'coach', 'squelch', 'wad']
# green ['green', 'greens', 'colors', 'parcel', 'greenness']
# doctor ['doctor', 'dr.', 'doc', 'physician', 'md']
# dog ['dog', 'tail', 'trying', 'run_down', 'quest']
# queen ['queen', 'queens', 'travelled', 'serve', 'lift']
# italy ['italy', 'italia', 'italian_republic', 'urban_center', 'city']
# 1090000 8858.34947669506
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'think_of']
# bus ['bus', 'buss', 'coach', 'car', 'passel']
# green ['green', 'greens', 'greenness', 'colors', 'chromatic']
# doctor ['doctor', 'physician', 'dr.', 'doc', 'md']
# dog ['dog', 'run_down', 'tail', 'trying', 'risk']
# queen ['queen', 'queens', 'fly', 'king', 'travelled']
# italy ['italy', 'italia', 'italian_republic', 'terrorism', 'fto']
# 1100000 8869.740139126778
# ...
# green ['green', 'greens', 'chromatic', 'crimson', 'color']
# doctor ['doctor', 'md', 'medico', 'fixing', 'dr.']
# dog ['dog', 'trail', 'domestic_dog', 'arrest', 'support']
# queen ['queen', 'queens', 'royal_line', 'fagot', 'poof']
# italy ['italy', 'italia', 'italian_republic', 'spain', 'italian_region']
# 1640000 8898.03338444233
# girl ['girl', 'miss', 'missy', 'young_lady', 'fille']
# bus ['bus', 'buss', 'motorcoach', 'coach', 'autobus']
# green ['green', 'greens', 'chromatic', 'color', 'placed']
# doctor ['doctor', 'medico', 'md', 'physician', 'dr.']
# dog ['dog', 'domestic_dog', 'arrest', 'run_down', 'mate']
# queen ['queen', 'queens', 'royal_line', 'flies', 'wander']
# italy ['italy', 'italia', 'italian_republic', 'spain', 'italian_region']
# 1650000 8884.850649476051
# girl ['girl', 'miss', 'missy', 'young_lady', 'fille']
# bus ['bus', 'buss', 'coach', 'motorbus', 'car']
# green ['green', 'greens', 'chromatic', 'crimson', 'colored']
# doctor ['doctor', 'medico', 'md', 'physician', 'dr.']
# dog ['dog', 'arrest', 'trail', 'mate', 'chase']
# queen ['queen', 'queens', 'royal_line', 'flies', 'king']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'finland']
# 1660000 8893.249262869358
# girl ['girl', 'miss', 'missy', 'woman', 'fille']
# bus ['bus', 'buss', 'coach', 'autobus', 'motorcoach']
# green ['green', 'greens', 'chromatic', 'crimson', 'shoot']
# doctor ['doctor', 'medico', 'md', 'dr.', 'physician']
# dog ['dog', 'chase', 'domestic_dog', 'run_down', 'arrest']
# queen ['queen', 'queens', 'marks', 'disparagement', 'drift']
# italy ['italy', 'italian_republic', 'italia', 'spain', 'italian_region']
# 1670000 8896.78470158577
# girl ['girl', 'miss', 'missy', 'woman', 'young_woman']
# bus ['bus', 'buss', 'car', 'coach', 'motorcoach']
# green ['green', 'greens', 'chromatic', 'planting', 'common']
# doctor ['doctor', 'md', 'dr.', 'physician', 'fixing']
# dog ['dog', 'make_out', 'chase', 'tail', 'arrest']
# queen ['queen', 'queens', 'disparagement', 'drift', 'child']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'deutschland']
# 1680000 8903.753122866154
# girl ['girl', 'miss', 'missy', 'fille', 'baby']
# bus ['bus', 'buss', 'car', 'coach', 'machine']
# green ['green', 'greens', 'chromatic', 'common', 'viridity']
# doctor ['doctor', 'md', 'dr.', 'physician', 'brace']
# dog ['dog', 'domestic_dog', 'tail', 'elude', 'run_down']
# queen ['queen', 'queens', 'drift', 'mark', 'marks']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'deutschland']
# 1690000 8907.490003943443
# girl ['girl', 'miss', 'missy', 'fille', 'takings']
# bus ['bus', 'buss', 'car', 'coach', 'automobile']
# green ['green', 'greens', 'viridity', 'chromatic', 'park']
# doctor ['doctor', 'dr.', 'md', 'physician', 'father']
# dog ['dog', 'tail', 'elude', 'make_out', 'shit']
# queen ['queen', 'queens', 'drift', 'marks', 'faggot']
# italy ['italy', 'italia', 'italian_republic', 'italian_region', 'deutschland']
# 1700000 8903.735570967197
# girl ['girl', 'miss', 'young_lady', 'young_woman', 'woman']
# bus ['bus', 'buss', 'coach', 'car', 'heap']
# green ['green', 'greens', 'viridity', 'park', 'chromatic']
# doctor ['doctor', 'dr.', 'physician', 'md', 'medico']
# dog ['dog', 'tail', 'chase_after', 'support', 'shit']
# queen ['queen', 'queens', 'faggot', 'drift', 'played']
# italy ['italy', 'italian_republic', 'italia', 'city', 'italian_region']
# 1710000 8891.052758812904
# girl ['girl', 'miss', 'young_lady', 'young_woman', 'woman']
# bus ['bus', 'coach', 'buss', 'car', 'autobus']
# green ['green', 'greens', 'viridity', 'park', 'chromatic']
# doctor ['doctor', 'physician', 'dr.', 'md', 'medico']
# dog ['dog', 'domestic_dog', 'support', 'quest', 'hound']
# queen ['queen', 'queens', 'marks', 'fag', 'faggot']
# italy ['italy', 'italian_republic', 'italia', 'european_union', 'city']
# 1720000 8902.859845936298
# girl ['girl', 'miss', 'young_lady', 'woman', 'missy']
# bus ['bus', 'coach', 'motorcoach', 'rider', 'heaps']
# green ['green', 'greens', 'viridity', 'chromatic', 'ks']
# doctor ['doctor', 'md', 'dr.', 'medico', 'fixings']
# dog ['dog', 'support', 'domestic_dog', 'chase', 'hound']
# queen ['queen', 'queens', 'fag', 'faggot', 'drift']
# italy ['italy', 'italia', 'italian_republic', 'pitched_battle', 'european_union']
# 1730000 8900.56344473362
# girl ['girl', 'miss', 'young_woman', 'young_lady', 'missy']
# bus ['bus', 'motorbus', 'coach', 'car', 'machine']
# green ['green', 'greens', 'running', 'park', 'chromatic']
# doctor ['doctor', 'medico', 'dr.', 'fixings', 'physician']
# dog ['dog', 'chase', 'domestic_dog', 'tag', 'track']
# queen ['queen', 'queens', 'fag', 'mark', 'drift']
# italy ['italy', 'italian_republic', 'italia', 'pitched_battle', 'italian_region']
# 1740000 8897.315929174423
# girl ['girl', 'miss', 'woman', 'young_woman', 'missy']
# bus ['bus', 'car', 'machine', 'coach', 'buss']
# green ['green', 'greens', 'running', 'develop', 'park']
# doctor ['doctor', 'fixings', 'medico', 'md', 'specialist']
# dog ['dog', 'tag', 'chase', 'domestic_dog', 'hook']
# queen ['queen', 'queens', 'fag', 'disparagement', 'faggot']
# italy ['italy', 'italian_republic', 'italia', 'pitched_battle', 'italian_region']
# 1750000 8921.605984568596
# girl ['girl', 'miss', 'woman', 'missy', 'young_woman']
# bus ['bus', 'coach', 'car', 'buss', 'machine']
# green ['green', 'greens', 'colouring', 'stimulate', 'running']
# doctor ['doctor', 'md', 'fixings', 'medico', 'dr.']
# dog ['dog', 'tag', 'dropping', 'catch', 'flag']
# queen ['queen', 'queens', 'fag', 'mark', 'draw']
# italy ['italy', 'italian_republic', 'italia', 'pitched_battle', 'italian_region']
# 1760000 8904.765096187592
# girl ['girl', 'miss', 'woman', 'young_woman', 'missy']
# bus ['bus', 'buss', 'coach', 'machine', 'car']
# green ['green', 'greens', 'colouring', 'chromatic', 'colored']
# doctor ['doctor', 'md', 'dr.', 'physician', 'fixings']
# dog ['dog', 'domestic_dog', 'chase', 'run_down', 'dropping']
# queen ['queen', 'queens', 'fag', 'faggot', 'fagot']
# italy ['italy', 'italia', 'italian_republic', 'pitched_battle', 'italian_region']
# 1770000 8894.346966207027
# girl ['girl', 'miss', 'woman', 'missy', 'female']
# bus ['bus', 'buss', 'autobus', 'car', 'motorcoach']
# green ['green', 'greens', 'chromatic', 'park', 'color']
# doctor ['doctor', 'md', 'dr.', 'repair', 'doc']
# dog ['dog', 'domestic_dog', 'chase', 'hook', 'support']
# queen ['queen', 'queens', 'fag', 'rise', 'bind']
# italy ['italy', 'italian_republic', 'italia', 'pitched_battle', 'river']
# 1780000 8908.387778818607
# girl ['girl', 'miss', 'woman', 'missy', 'young_woman']
# bus ['bus', 'motorbus', 'autobus', 'buss', 'passenger_vehicle']
# green ['green', 'greens', 'chromatic', 'color', 'colored']
# doctor ['doctor', 'md', 'doc', 'dr.', 'regenerate']
# dog ['dog', 'domestic_dog', 'chase', 'chased', 'hook']
# queen ['queen', 'queens', 'fag', 'faggot', 'rise']
# italy ['italy', 'italian_republic', 'pitched_battle', 'italia', 'ireland']
# 1790000 8893.15651088953
# girl ['girl', 'miss', 'woman', 'female', 'young_lady']
# bus ['bus', 'buss', 'coach', 'autobus', 'passenger_vehicle']
# green ['green', 'greens', 'chromatic', 'provide', 'park']
# doctor ['doctor', 'md', 'dr.', 'doc', 'physician']
# dog ['dog', 'domestic_dog', 'chase', 'tag', 'catch']
# queen ['queen', 'queens', 'fag', 'disparagement', 'faggot']
# italy ['italy', 'italian_republic', 'italia', 'pitched_battle', 'ireland']
# 1800000 8904.885095655918
# girl ['girl', 'miss', 'woman', 'young_lady', 'female']
# bus ['bus', 'buss', 'motorcar', 'coach', 'motorbus']
# green ['green', 'greens', 'chromatic', 'provide', 'park']
# doctor ['doctor', 'carry', 'md', 'dr.', 'repair']
# dog ['dog', 'domestic_dog', 'tag', 'chase', 'blackguard']
# queen ['queen', 'queens', 'fag', 'faggot', 'disparagement']
# italy ['italy', 'italian_republic', 'italia', 'pitched_battle', 'river']
# 1810000 8907.292154073715
# girl ['girl', 'miss', 'young_woman', 'woman', 'young_lady']
# bus ['bus', 'buss', 'window', 'machine', 'public_transport']
# green ['green', 'greens', 'chromatic', 'park', 'greenness']
# doctor ['doctor', 'dr.', 'md', 'doc', 'medico']
# dog ['dog', 'domestic_dog', 'tag', 'pursue', 'capture']
# queen ['queen', 'queens', 'faggot', 'disparagement', 'poove']
# italy ['italy', 'italian_republic', 'pitched_battle', 'italia', 'river']
# 1820000 8909.855333805084
# girl ['girl', 'miss', 'woman', 'young_woman', 'young_lady']
# bus ['bus', 'buss', 'machine', 'passenger_vehicle', 'window']
# green ['green', 'greens', 'chromatic', 'park', 'color']
# doctor ['doctor', 'dr.', 'doc', 'medico', 'physician']
# dog ['dog', 'chase', 'tag', 'domestic_dog', 'abuse']
# queen ['queen', 'queens', 'disparagement', 'faggot', 'theater']
# italy ['italy', 'italian_republic', 'italia', 'ireland', 'pitched_battle']
# 1830000 8922.838659286499
# girl ['girl', 'miss', 'woman', 'young_woman', 'boast']
# bus ['bus', 'buss', 'machine', 'motorbus', 'window']
# green ['green', 'greens', 'chromatic', 'colored', 'fancify']
# doctor ['doctor', 'physician', 'medico', 'dr.', 'md']
# dog ['dog', 'track', 'chase', 'tag', 'pursue']
# queen ['queen', 'queens', 'disparagement', 'theater', 'faggot']
# italy ['italy', 'italian_republic', 'italia', 'pitched_battle', 'france']
# 1840000 8903.637515127659
# girl ['girl', 'miss', 'woman', 'young_woman', 'lose']
# bus ['bus', 'buss', 'machine', 'window', 'motorbus']
# green ['green', 'greens', 'chromatic', 'coloured', 'park']
# doctor ['doctor', 'dr.', 'medico', 'md', 'physician']
# dog ['dog', 'domestic_dog', 'tag', 'hooks', 'tear']
# queen ['queen', 'queens', 'poove', 'faggot', 'disparagement']
# italy ['italy', 'italia', 'italian_republic', 'metropolis', 'france']
# 1850000 8920.1440269351
# girl ['girl', 'miss', 'woman', 'lose', 'young_woman']
# bus ['bus', 'machine', 'public_transport', 'buss', 'coach']
# green ['green', 'greens', 'colored', 'coloured', 'develop']
# doctor ['doctor', 'dr.', 'md', 'medico', 'physician']
# dog ['dog', 'stagger', 'domestic_dog', 'track', 'chase']
# queen ['queen', 'queens', 'gay_man', 'fairy', 'faggot']
# italy ['italy', 'italian_republic', 'italia', 'urban_center', 'france']
# 1860000 8906.129594922066
# girl ['girl', 'miss', 'woman', 'combust', 'young_woman']
# bus ['bus', 'buss', 'public_transport', 'machine', 'motorcoach']
# green ['green', 'greens', 'colored', 'park', 'coloured']
# doctor ['doctor', 'dr.', 'md', 'physician', 'medico']
# dog ['dog', 'domestic_dog', 'chase', 'give_chase', 'blackguard']
# queen ['queen', 'queens', 'faggot', 'fairy', 'gay_man']
# italy ['italy', 'italia', 'italian_republic', 'metropolis', 'france']
# 1870000 8900.013529121876
# girl ['girl', 'miss', 'woman', 'travelling', 'blow']
# bus ['bus', 'buss', 'machine', 'train', 'public_transport']
# green ['green', 'greens', 'park', 'colored', 'crimson']
# doctor ['doctor', 'physician', 'dr.', 'md', 'medico']
# dog ['dog', 'tag', 'domestic_dog', 'chase', 'blackguard']
# queen ['queen', 'queens', 'faggot', 'fagot', 'slang']
# italy ['italy', 'italia', 'italian_republic', 'terrorism', 'spain']
# 1880000 8916.222307026386
# girl ['girl', 'miss', 'woman', 'young_woman', 'missy']
# bus ['bus', 'buss', 'train', 'machine', 'coach']
# green ['green', 'greens', 'chromatic', 'colored', 'park']
# doctor ['doctor', 'dr.', 'physician', 'md', 'medico']
# dog ['dog', 'tag', 'blackguard', 'track', 'learn']
# queen ['queen', 'queens', 'faggot', 'bull', 'slang']
# italy ['italy', 'italia', 'italian_republic', 'spain', 'france']
# 1890000 8913.329632163048
# girl ['girl', 'miss', 'woman', 'young_woman', 'fille']
# bus ['bus', 'buss', 'train', 'machine', 'visit']
# green ['green', 'greens', 'chromatic', 'park', 'colored']
# doctor ['doctor', 'md', 'dr.', 'physician', 'doc']
# dog ['dog', 'track', 'tag', 'tail', 'blackguard']
# queen ['queen', 'queens', 'faggot', 'fagot', 'fairy']
# italy ['italy', 'italian_republic', 'italia', 'france', 'spain']
# 1900000 8909.465346872807
# girl ['girl', 'miss', 'woman', 'blow', 'pass']
# bus ['bus', 'buss', 'train', 'coach', 'machine']
# green ['green', 'greens', 'chromatic', 'colored', 'park']
# doctor ['doctor', 'dr.', 'md', 'physician', 'medico']
# dog ['dog', 'tag', 'track', 'hook', 'blackguard']
# queen ['queen', 'queens', 'king', 'fairy', 'faggot']
# italy ['italy', 'italian_republic', 'italia', 'france', 'spain']
# 1910000 8916.488118946552
# girl ['girl', 'miss', 'woman', 'blow', 'fille']
# bus ['bus', 'buss', 'train', 'taking', 'machine']
# green ['green', 'greens', 'chromatic', 'colored', 'drawn']
# doctor ['doctor', 'dr.', 'md', 'physician', 'medico']
# dog ['dog', 'tag', 'run_down', 'tail', 'loot']
# queen ['queen', 'queens', 'faggot', 'king', 'gay_man']
# italy ['italy', 'italian_republic', 'italia', 'spain', 'geographical_region']
# 1920000 8904.848816394806
# girl ['girl', 'miss', 'blow', 'fille', 'woman']
# bus ['bus', 'buss', 'machine', 'train', 'pulling']
# green ['green', 'greens', 'chromatic', 'colored', 'prime']
# doctor ['doctor', 'dr.', 'md', 'physician', 'doc']
# dog ['dog', 'tag', 'blackguard', 'search', 'tease']
# queen ['queen', 'queens', 'faggot', 'poove', 'gay_man']
# italy ['italy', 'italia', 'italian_republic', 'france', 'germany']
# 1930000 8914.543902039528
# girl ['girl', 'miss', 'fille', 'woman', 'blow']
# bus ['bus', 'buss', 'coach', 'train', 'roof']
# green ['green', 'greens', 'chromatic', 'colored', 'uprise']
# doctor ['doctor', 'md', 'doc', 'down', 'dr.']
# dog ['dog', 'tag', 'blackguard', 'run_down', 'tease']
# queen ['queen', 'queens', 'faggot', 'fagot', 'king']
# italy ['italy', 'italian_republic', 'italia', 'germany', 'port']
# 1940000 8908.279875099659
# girl ['girl', 'miss', 'fille', 'woman', 'baby']
# bus ['bus', 'buss', 'coach', 'omnibus', 'train']
# green ['green', 'greens', 'chromatic', 'made', 'prepare']
# doctor ['doctor', 'md', 'medico', 'vet', 'doc']
# dog ['dog', 'tag', 'hook', 'run_down', 'crack']
# queen ['queen', 'queens', 'faggot', 'promote', 'fagot']
# italy ['italy', 'italian_republic', 'italia', 'spain', 'pitched_battle']
# 1950000 8917.025674283504
# girl ['girl', 'miss', 'fille', 'woman', 'missy']
# bus ['bus', 'buss', 'train', 'coach', 'removed']
# green ['green', 'greens', 'chromatic', 'k', 'colored']
# doctor ['doctor', 'doc', 'md', 'medico', 'fix']
# dog ['dog', 'tag', 'run_down', 'tease', 'go_after']
# queen ['queen', 'queens', 'promote', 'increase', 'king']
# italy ['italy', 'spain', 'italia', 'italian_republic', 'pitched_battle']
# 1960000 8918.72321152687
# girl ['girl', 'miss', 'fille', 'dame', 'missy']
# bus ['bus', 'buss', 'coach', 'prepare', 'train']
# green ['green', 'greens', 'k', 'chromatic', 'colored']
# doctor ['doctor', 'doc', 'md', 'dr.', 'fix']
# dog ['dog', 'tag', 'run_down', 'tail', 'domestic_dog']
# queen ['queen', 'queens', 'chess', 'increase', 'faggot']
# italy ['italy', 'italia', 'italian_republic', 'spain', 'pitched_battle']
# 1970000 8903.006738603115
# girl ['girl', 'miss', 'woman', 'fille', 'missy']
# bus ['bus', 'prepare', 'train', 'coach', 'making']
# green ['green', 'greens', 'k', 'chromatic', 'color']
# doctor ['doctor', 'doc', 'down', 'md', 'gilbert']
# dog ['dog', 'hound', 'tail', 'tag', 'run_down']
# queen ['queen', 'queens', 'compel', 'fagot', 'fly']
# italy ['italy', 'italia', 'italian_republic', 'spain', 'ireland']
# 1980000 8919.666934072971
# girl ['girl', 'miss', 'fille', 'missy', 'woman']
# bus ['bus', 'coach', 'train', 'buss', 'slews']
# green ['green', 'greens', 'k', 'chromatic', 'color']
# doctor ['doctor', 'doc', 'md', 'medico', 'repair']
# dog ['dog', 'tail', 'tag', 'run_down', 'tracked']
# queen ['queen', 'queens', 'king', 'fagot', 'effect']
# italy ['italy', 'italia', 'italian_republic', 'spain', 'france']
# 1990000 8910.944380700588
# girl ['girl', 'miss', 'missy', 'fille', 'young_woman']
# bus ['bus', 'coach', 'buss', 'heap', 'create']
# green ['green', 'greens', 'k', 'chromatic', 'blue']
# doctor ['doctor', 'doc', 'rectify', 'gilbert', 'physician']
# dog ['dog', 'tag', 'quest', 'tail', 'plunder']
# queen ['queen', 'queens', 'king', 'drawing', 'getting']
# italy ['italy', 'italia', 'italian_republic', 'spain', 'pitched_battle']
# 2000000 8902.890990197659
# girl ['girl', 'miss', 'fille', 'missy', 'boast']
# bus ['bus', 'coach', 'heap', 'buss', 'jitney']
# green ['green', 'greens', 'k', 'chromatic', 'colour']
# doctor ['doctor', 'doc', 'dr.', 'medico', 'physician']
# dog ['dog', 'tag', 'quest', 'plunder', 'tail']
# queen ['queen', 'queens', 'king', 'faggot', 'effect']
# italy ['italy', 'italian_republic', 'italia', 'spain', 'france']

# %%
model = torch.load('models/wordnet_2000000.model')

test(['girl', 'bus', 'green', 'doctor', 'dog', 'queen', 'italy'])
# Out:
# girl ['girl', 'miss', 'fille', 'missy', 'boast']
# bus ['bus', 'coach', 'heap', 'buss', 'jitney']
# green ['green', 'greens', 'k', 'chromatic', 'colour']
# doctor ['doctor', 'doc', 'dr.', 'medico', 'physician']
# dog ['dog', 'tag', 'quest', 'plunder', 'tail']
# queen ['queen', 'queens', 'king', 'faggot', 'effect']
# italy ['italy', 'italian_republic', 'italia', 'spain', 'france']
